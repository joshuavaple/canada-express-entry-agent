# %%
# %sh ls

# %%
# %sh uv --version

# %%
# run the start-server below in the web terminal
# %sh uv run start-server

# %%
# %sh curl -X POST http://localhost:8000/invocations \
   -H "Content-Type: application/json" \
   -d '{
    "input": [{ "role": "user", "content": "tell me more about the express entry system"}],
    "stream": true
    }'

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
endpoint = w.secrets.get_secret(scope="demo-scope", key="azure_openai_endpoint").value
# print(f"Current endpoint: '{endpoint}'")
